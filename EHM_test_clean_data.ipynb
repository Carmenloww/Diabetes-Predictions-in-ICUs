# %%
import pandas as pd

# %%
df = pd.read_csv('Resources/TrainingWiDS2021.csv')

print(df.shape)
df.head()
# Out:
# (130157, 181)
#    Unnamed: 0  encounter_id  hospital_id   age        bmi  elective_surgery  \
# 0           1        214826          118  68.0  22.732803                 0
# 1           2        246060           81  77.0  27.421875                 0
# 2           3        276985          118  25.0  31.952749                 0
# 3           4        262220          118  81.0  22.635548                 1
# 4           5        201746           33  19.0        NaN                 0
#
#    ethnicity gender  height hospital_admit_source  ... h1_pao2fio2ratio_max  \
# 0  Caucasian      M   180.3                 Floor  ...                  NaN
# 1  Caucasian      F   160.0                 Floor  ...                 51.0
# 2  Caucasian      F   172.7  Emergency Department  ...                  NaN
# 3  Caucasian      F   165.1        Operating Room  ...                337.0
# 4  Caucasian      M   188.0                   NaN  ...                  NaN
#
# ...

# %%
# Remove rows that have at least 1 null value.
df = df.dropna()
print(df.shape)
df.head()
# Out:
# (63, 181)
#       Unnamed: 0  encounter_id  hospital_id   age        bmi  \
# 8230        8231        232100           89  67.0  28.146291
# 8435        8436        275481           89  60.0  34.574559
# 8657        8658        278577           89  66.0  25.775925
# 8667        8668        278295           89  55.0  56.659238
# 9170        9171        236541           89  21.0  22.180764
#
#       elective_surgery      ethnicity gender  height hospital_admit_source  \
# 8230                 0      Caucasian      M  167.64          Direct Admit
# 8435                 0      Caucasian      M  177.80          Direct Admit
# 8657                 1      Caucasian      M  185.40        Operating Room
# 8667                 0  Other/Unknown      F  162.60        Operating Room
# 9170                 0      Caucasian      M  182.90          Direct Admit
#
#       ... h1_pao2fio2ratio_max  h1_pao2fio2ratio_min aids cirrhosis  \
# ...

# %%
df.to_csv('Resources/EHM_test_db.csv')
